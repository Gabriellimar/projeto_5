# %%
import pandas as pd
import numpy as np

# %%
df19 = pd.read_csv('/content/Ano2019.csv', delimiter=';')
df19.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento vlrRestituicao  \
# 0           NaN       NaN  1554246               NaN            NaN
# 1           NaN       NaN  1570078               NaN            NaN
# 2           NaN       NaN  1570503               NaN            NaN
# 3           NaN       NaN  1579375               NaN            NaN
# 4           NaN       NaN  1590980               NaN            NaN
#
#    nuDeputadoId  ideDocumento  \
# 0          2812       6738121
# 1          2812       6769606
# 2          2812       6771099
# 3          2812       6793690
# 4          2812       6821674
#
#                                         urlDocumento
# 0  http://camara.leg.br/cota-parlamentar/nota-fis...
# 1  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2  http://camara.leg.br/cota-parlamentar/nota-fis...
# 3  http://camara.leg.br/cota-parlamentar/nota-fis...
# 4  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [5 rows x 31 columns]

# %% [markdown]
# Obter os tipos de despesas realizadas.

# %%
tipo_despesa = (df19["txtDescricao"])
print(tipo_despesa)
# Out:
# 0                FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 1                FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 2                FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 3                FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 4                FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
#                                 ...
# 288987                                 PASSAGEM AÉREA - RPA
# 288988    MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 288989                           PASSAGEM AÉREA - REEMBOLSO
# 288990                                            TELEFONIA
# 288991        LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# Name: txtDescricao, Length: 288992, dtype: object

# %% [markdown]
# A soma dos gastos relacionados a legislatura

# %%
print(df19.groupby(by=['nuLegislatura','vlrLiquido']).sum())
# Out:
#                                    cpf  ideCadastro  nuCarteiraParlamentar  \
# nuLegislatura vlrLiquido
# 2015          -3242.02    6.053872e+08      74075.0                   21.0
#               -2486.07    3.336124e+09      73560.0                  391.0
#               -2484.29    5.709091e+09     234090.0                  582.0
#               -2428.94    1.968611e+10     178938.0                  289.0
#               -2104.87    7.498991e+10      74439.0                  164.0
# ...                                ...          ...                    ...
# 2019           90000.00   8.570261e+10     204547.0                  257.0
#                96000.00   1.960970e+09      74419.0                  143.0
#                109500.00  4.319693e+10     160639.0                   67.0
#                110000.00  1.767254e+10     204567.0                  211.0
#                145140.00  8.471985e+10     160518.0                  270.0
#
#                           codLegislatura  numSubCota  numEspecificacaoSubCota  \
# nuLegislatura vlrLiquido
# 2015          -3242.02                55         999                        0
#               -2486.07                55         999                        0
#               -2484.29               110        1998                        0
#               -2428.94                55         999                        0
#               -2104.87                55         999                        0
# ...                                  ...         ...                      ...
# 2019           90000.00               56           5                        0
#                96000.00               56           5                        0
#                109500.00              56           5                        0
#                110000.00              56           5                        0
#                145140.00              56           5                        0
#
#                           indTipoDocumento  vlrDocumento  vlrGlosa  numMes  \
# nuLegislatura vlrLiquido
# 2015          -3242.02                   0      -3242.02       0.0       1
#               -2486.07                   0      -2486.07       0.0       1
#               -2484.29                   0      -4968.58       0.0       2
#               -2428.94                   0      -2428.94       0.0       1
#               -2104.87                   0      -2104.87       0.0       1
# ...                                    ...           ...       ...     ...
# 2019           90000.00                  0      90000.00       0.0      12
#                96000.00                  0      96000.00       0.0       4
#                109500.00                 0     109500.00       0.0      12
#                110000.00                 0     110000.00       0.0      11
#                145140.00                 0     145140.00       0.0      12
#
#                           numAno  numParcela  numLote  numRessarcimento  \
# nuLegislatura vlrLiquido
# 2015          -3242.02      2019           0        0               0.0
#               -2486.07      2019           0        0               0.0
#               -2484.29      4038           0        0               0.0
#               -2428.94      2019           0        0               0.0
#               -2104.87      2019           0        0               0.0
# ...                          ...         ...      ...               ...
# 2019           90000.00     2019           0  1665911               0.0
#                96000.00     2019           0  1589271               0.0
#                109500.00    2019           0  1661126               0.0
#                110000.00    2019           0  1656271               0.0
#                145140.00    2019           0  1679887               0.0
#
#                           vlrRestituicao  nuDeputadoId  ideDocumento
# nuLegislatura vlrLiquido
# 2015          -3242.02               0.0          1011       1633156
#               -2486.07               0.0          1175       1633791
#               -2484.29               0.0          3470       3269923
#               -2428.94               0.0          3075       1633157
#               -2104.87               0.0          1198       1633562
# ...                                  ...           ...           ...
# 2019           90000.00              0.0          3221       6991485
#                96000.00              0.0           137       6817912
#                109500.00             0.0          2300       6981838
#                110000.00             0.0          3426       6971267
#                145140.00             0.0          2233       7020514
#
# [73551 rows x 17 columns]

# %% [markdown]
# A média dos valores gastos em cada despesa

# %%
print(df19.groupby(by=['vlrLiquido','txtDescricao']).mean())
# Out:
#                                                           cpf  ideCadastro  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA               7.705036e+10     204423.0
# -7154.06   PASSAGEM AÉREA - SIGEPA               7.705036e+10     204423.0
# -6605.57   PASSAGEM AÉREA - RPA                  4.789114e+09      74554.0
# -6206.76   PASSAGEM AÉREA - RPA                  1.302359e+10      74459.0
# -5764.46   PASSAGEM AÉREA - SIGEPA               7.705036e+10     204423.0
# ...                                                       ...          ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  8.570261e+10     204547.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1.960970e+09      74419.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  4.319693e+10     160639.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1.767254e+10     204567.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  8.471985e+10     160518.0
#
#                                                  nuCarteiraParlamentar  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                               139.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                               139.0
# -6605.57   PASSAGEM AÉREA - RPA                                  203.0
# -6206.76   PASSAGEM AÉREA - RPA                                  109.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                               139.0
# ...                                                                ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                  257.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                  143.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                   67.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                  211.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                  270.0
#
#                                                  nuLegislatura  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                      2019.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                      2019.0
# -6605.57   PASSAGEM AÉREA - RPA                         2019.0
# -6206.76   PASSAGEM AÉREA - RPA                         2019.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                      2019.0
# ...                                                        ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.         2019.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.         2019.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.         2019.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.         2019.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.         2019.0
#
#                                                  codLegislatura  numSubCota  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                         56.0       998.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                         56.0       998.0
# -6605.57   PASSAGEM AÉREA - RPA                            56.0       999.0
# -6206.76   PASSAGEM AÉREA - RPA                            56.0       999.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                         56.0       998.0
# ...                                                         ...         ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.            56.0         5.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.            56.0         5.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.            56.0         5.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.            56.0         5.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.            56.0         5.0
#
#                                                  numEspecificacaoSubCota  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                                   0.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                                   0.0
# -6605.57   PASSAGEM AÉREA - RPA                                      0.0
# -6206.76   PASSAGEM AÉREA - RPA                                      0.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                                   0.0
# ...                                                                  ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                      0.0
#
#                                                  indTipoDocumento  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                            0.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                            0.0
# -6605.57   PASSAGEM AÉREA - RPA                               0.0
# -6206.76   PASSAGEM AÉREA - RPA                               0.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                            0.0
# ...                                                           ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.               0.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.               0.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.               0.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.               0.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.               0.0
#
#                                                  vlrDocumento  vlrGlosa  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                    7821.20       0.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                    7154.06       0.0
# -6605.57   PASSAGEM AÉREA - RPA                      -6605.57       0.0
# -6206.76   PASSAGEM AÉREA - RPA                      -6206.76       0.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                    5764.46       0.0
# ...                                                       ...       ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.      90000.00       0.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.      96000.00       0.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     109500.00       0.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     110000.00       0.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     145140.00       0.0
#
#                                                  numMes  numAno  numParcela  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                 12.0  2019.0         0.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                 12.0  2019.0         0.0
# -6605.57   PASSAGEM AÉREA - RPA                     9.0  2019.0         0.0
# -6206.76   PASSAGEM AÉREA - RPA                     6.0  2019.0         0.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                 12.0  2019.0         0.0
# ...                                                 ...     ...         ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.    12.0  2019.0         0.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     4.0  2019.0         0.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.    12.0  2019.0         0.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.    11.0  2019.0         0.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.    12.0  2019.0         0.0
#
#                                                    numLote  numRessarcimento  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                     0.0               0.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                     0.0               0.0
# -6605.57   PASSAGEM AÉREA - RPA                        0.0               0.0
# -6206.76   PASSAGEM AÉREA - RPA                        0.0               0.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                     0.0               0.0
# ...                                                    ...               ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1665911.0               NaN
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1589271.0               NaN
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1661126.0               NaN
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1656271.0               NaN
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  1679887.0               NaN
#
#                                                  vlrRestituicao  nuDeputadoId  \
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                          NaN        3368.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                          NaN        3368.0
# -6605.57   PASSAGEM AÉREA - RPA                             NaN        1071.0
# -6206.76   PASSAGEM AÉREA - RPA                             NaN          74.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                          NaN        3368.0
# ...                                                         ...           ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.             NaN        3221.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.             NaN         137.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.             NaN        2300.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.             NaN        3426.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.             NaN        2233.0
#
#                                                  ideDocumento
# vlrLiquido txtDescricao
# -7821.20   PASSAGEM AÉREA - SIGEPA                     3932.0
# -7154.06   PASSAGEM AÉREA - SIGEPA                     3925.0
# -6605.57   PASSAGEM AÉREA - RPA                     1702302.0
# -6206.76   PASSAGEM AÉREA - RPA                     1675369.0
# -5764.46   PASSAGEM AÉREA - SIGEPA                     3935.0
# ...                                                       ...
#  90000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     6991485.0
#  96000.00  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     6817912.0
#  109500.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     6981838.0
#  110000.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     6971267.0
#  145140.00 DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.     7020514.0
#
# [94668 rows x 18 columns]

# %% [markdown]
# O valor mínimo gasto

# %%
print(df19.groupby(by=['nuLegislatura','vlrLiquido']).min())
# Out:
#                                           txNomeParlamentar           cpf  \
# nuLegislatura vlrLiquido
# 2015          -3242.02                     Elcione Barbalho  6.053872e+08
#               -2486.07                        SILVIO TORRES  3.336124e+09
#               -2484.29                    ANTONIO IMBASSAHY  2.372968e+09
#               -2428.94                         CABO DACIOLO  1.968611e+10
#               -2104.87                       Wolney Queiroz  7.498991e+10
# ...                                                     ...           ...
# 2019           90000.00                           Léo Motta  8.570261e+10
#                96000.00                    Gonzaga Patriota  1.960970e+09
#                109500.00  Professora Dorinha Seabra Rezende  4.319693e+10
#                110000.00                     Raimundo Costa  1.767254e+10
#                145140.00                      Weliton Prado  8.471985e+10
#
#                           ideCadastro  nuCarteiraParlamentar  codLegislatura  \
# nuLegislatura vlrLiquido
# 2015          -3242.02        74075.0                   21.0              55
#               -2486.07        73560.0                  391.0              55
#               -2484.29        73560.0                  191.0              55
#               -2428.94       178938.0                  289.0              55
#               -2104.87        74439.0                  164.0              55
# ...                               ...                    ...             ...
# 2019           90000.00      204547.0                  257.0              56
#                96000.00       74419.0                  143.0              56
#                109500.00     160639.0                   67.0              56
#                110000.00     204567.0                  211.0              56
#                145140.00     160518.0                  270.0              56
#
#                           numSubCota                          txtDescricao  \
# nuLegislatura vlrLiquido
# 2015          -3242.02           999                  PASSAGEM AÉREA - RPA
#               -2486.07           999                  PASSAGEM AÉREA - RPA
#               -2484.29           999                  PASSAGEM AÉREA - RPA
#               -2428.94           999                  PASSAGEM AÉREA - RPA
#               -2104.87           999                  PASSAGEM AÉREA - RPA
# ...                              ...                                   ...
# 2019           90000.00            5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#                96000.00            5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#                109500.00           5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#                110000.00           5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#                145140.00           5  DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#
#                           numEspecificacaoSubCota        txtNumero  \
# nuLegislatura vlrLiquido
# 2015          -3242.02                          0      Comp-LHPPFC
#               -2486.07                          0  Comp-2442978535
#               -2484.29                          0  Comp-2442978525
#               -2428.94                          0      Comp-RLMVXW
#               -2104.87                          0      Comp-IE417L
# ...                                           ...              ...
# 2019           90000.00                         0              228
#                96000.00                         0              386
#                109500.00                        0  201900000003750
#                110000.00                        0         00002981
#                145140.00                        0            12497
#
#                           indTipoDocumento  vlrDocumento  vlrGlosa  numMes  \
# nuLegislatura vlrLiquido
# 2015          -3242.02                   0      -3242.02       0.0       1
#               -2486.07                   0      -2486.07       0.0       1
#               -2484.29                   0      -2484.29       0.0       1
#               -2428.94                   0      -2428.94       0.0       1
#               -2104.87                   0      -2104.87       0.0       1
# ...                                    ...           ...       ...     ...
# 2019           90000.00                  0      90000.00       0.0      12
#                96000.00                  0      96000.00       0.0       4
#                109500.00                 0     109500.00       0.0      12
#                110000.00                 0     110000.00       0.0      11
#                145140.00                 0     145140.00       0.0      12
#
#                           numAno  numParcela  numLote  numRessarcimento  \
# nuLegislatura vlrLiquido
# 2015          -3242.02      2019           0        0               0.0
#               -2486.07      2019           0        0               0.0
#               -2484.29      2019           0        0               0.0
#               -2428.94      2019           0        0               0.0
#               -2104.87      2019           0        0               0.0
# ...                          ...         ...      ...               ...
# 2019           90000.00     2019           0  1665911               NaN
#                96000.00     2019           0  1589271               NaN
#                109500.00    2019           0  1661126               NaN
#                110000.00    2019           0  1656271               NaN
#                145140.00    2019           0  1679887               NaN
#
#                           vlrRestituicao  nuDeputadoId  ideDocumento
# nuLegislatura vlrLiquido
# 2015          -3242.02               NaN          1011       1633156
#               -2486.07               NaN          1175       1633791
#               -2484.29               NaN          1175       1633790
#               -2428.94               NaN          3075       1633157
#               -2104.87               NaN          1198       1633562
# ...                                  ...           ...           ...
# 2019           90000.00              NaN          3221       6991485
#                96000.00              NaN           137       6817912
#                109500.00             NaN          2300       6981838
#                110000.00             NaN          3426       6971267
#                145140.00             NaN          2233       7020514
#
# [73551 rows x 20 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
